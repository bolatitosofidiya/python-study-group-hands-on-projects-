# %% [markdown]
# # Exercise 1

# %%
# Customer Registration System

customer_name ="Name: "
email_address = "Email: "
phone_number = "Phone: "
country = "Country: "
occupation ="Occupation: "

print("Customer Registration")

print(customer_name)
print(email_address)
print(phone_number)
print(country)
print(occupation)
# Out:
# Customer Registration
# Name:
# Email:
# Phone:
# Country:
# Occupation:

# %% [markdown]
# # Exercise 2

# %%
# Hospital Patient Record

hosiptal_records ="""PATIENT RECORD

Patient:
Doctor:
Diagnosis:
Blood Group:
Hospital:"""

print(hosiptal_records)
# Out:
# PATIENT RECORD
#
# Patient:
# Doctor:
# Diagnosis:
# Blood Group:
# Hospital:

# %% [markdown]
# # Exercise 3

# %%
# AI Prompt Builder

prompt ="""You are an AI Assistant.

Analyze customer feedback.

Identify common complaints.

Mention the most urgent complaint first.

Use simple language throughout the report.

Provide realistic recommendations.

Generate a summary report."""

print(prompt)
# Out:
# You are an AI Assistant.
#
# Analyze customer feedback.
#
# Identify common complaints.
#
# Mention the most urgent complaint first.
#
# Use simple language throughout the report.
#
# Provide realistic recommendations.
#
# Generate a summary report.

# %% [markdown]
# # Real-World Case Study Project

# %%
# Customer Feedback Management System

welcome_message = '''
Welcome to Insight Retail Technologies

Where customers feedback matters.'''

customer_feedback ="""
========================================
       CUSTOMER FEEDBACK REPORT
========================================

Customer Name : Sarah Johnson
Product       : Wireless Mouse
Category      : Computer Accessories
Rating        : 5 Stars

Customer Review
----------------------------------------
This is my first time using this product,
and l absolutely love it.
I'm definitely recommending it to others.

========================================
Thank you for your feedback!
========================================
Insight Retail Technologies
insightretail@gmail.com """

print(welcome_message)

print(customer_feedback)
# Out:
# Welcome to Insight Retail Technologies
#
# Where customers feedback matters.
#
# ...
#        CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name : Sarah Johnson
# Product       : Wireless Mouse
# Category      : Computer Accessories
# Rating        : 5 Stars
#
# Customer Review
# ----------------------------------------
# This is my first time using this product,
# and l absolutely love it.
# I'm definitely recommending it to others.
#
# ...
# Thank you for your feedback!
# ...
# Insight Retail Technologies
# insightretail@gmail.com
