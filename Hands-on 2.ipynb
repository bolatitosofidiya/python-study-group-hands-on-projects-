# %% [markdown]
# #  Excerise 1

# %%
# Creating Variables

name = "Loveth"
age = 29
country = "Nigeria"
print("Name:",name, "Age:",age, "Country:", country)
# Out:
# Name: Loveth Age: 29 Country: Nigeria

# %% [markdown]
# # Excerise 2

# %%
# Salary Calculation

basic_salary = 180000
bonus = 35000
total_salary = (basic_salary + bonus)
print(total_salary)
# Out:
# 215000

# %% [markdown]
# # Excerise 3

# %%
# User Input

name = input("Enter your name: ")
programming_language =input("Your favourite programming language: ")
print("Hello", name)
print("Your favourite programming language is", programming_language)
# Out:
# Enter your name: Bolatito
# Your favourite programming language: Python
# Hello Bolatito
# Your favourite programming language is Python

# %% [markdown]
# # Excerise 4

# %%
# Working with Data Types

name ="Cookies"
price = 1500
discount = 0.05
status = True

# %%
print(type(name))
print(type(price))
print(type(discount))
print(type(status))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # Excerise 5

# %%
# Dynamic Typing

amount = 14
print(type(amount))
# Out:
# <class 'int'>

# %%
print(type(amount))
# Out:
# <class 'str'>

# %% [markdown]
# # Mini Project

# %%
# Student Information Card

print("=================================")
print("    STUDENT INFORMATION CARD")
print("=================================")

name = input("Name: ")
age = int(input("Age: "))
programming_language = input("Course: ")
country = input("Country: ")
# Out:
# =================================
#     STUDENT INFORMATION CARD
# =================================
# Name: Glory
# Age: 21
# Course: Python
# Country: Nigeria

# %%
print(type(name))
print(type(age))
print(type(programming_language))
print(type(country))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
print(type(name))
print(type(age))
print(type(programming_language))
print(type(country))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
