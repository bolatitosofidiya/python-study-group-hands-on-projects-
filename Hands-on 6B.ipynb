# %% [markdown]
# # Excerise 1

# %%
# Employee Record Information Extractor (Human Resources)

employee_record = "EMP-HR-2026-004512"

print("Employee Prefix:",employee_record[:3])
print("Department:",employee_record[4:6])
print("Employment Year:",employee_record[7:11])
print("Employee Number:",employee_record[12:])
print("First 10 Characters:",employee_record[:10])
print("Last 6 Characters:",employee_record[12:])
print("Every Second Character:",employee_record[::2])
print("Every Third Character:",employee_record[::3])
print("Reverse:",employee_record[::-1])
# Out:
# Employee Prefix: EMP
# Department: HR
# Employment Year: 2026
# Employee Number: 004512
# First 10 Characters: EMP-HR-202
# Last 6 Characters: 004512
# Every Second Character: EPH-06041
# Every Third Character: E--205
# Reverse: 215400-6202-RH-PME

# %% [markdown]
# # Excerise 2

# %%
# Banking Card Security Formatter (Banking & Finance)

card_number = "5489123476549876"

print("First 4 digits",card_number[:4])
print("Last 4 digits:",card_number[12:16])
print("Middle 8 digits",card_number[4:12])
print("Every second digit:",card_number[::2])
print("Every third digit:",card_number[::3])
print("Entire card number in reverse:",card_number[::-1])
print("The last 8 digits in reverse order:",card_number[16:7:-1])
print("**** **** ****",card_number[12:16])
# Out:
# First 4 digits 5489
# Last 4 digits: 9876
# Middle 8 digits 12347654
# Every second digit: 58137597
# Every third digit: 593696
# Entire card number in reverse: 6789456743219845
# The last 8 digits in reverse order: 67894567
# **** **** **** 9876

# %% [markdown]
# # Excerise 3

# %%
# Customer Information Processor (Retail Analytics)

customer_record = "CUS-LAG-2026-000451"

print("Customer Prefix:",customer_record[:3])
print("City Code:",customer_record[4:7])
print("Registration Year:",customer_record[8:12])
print("Customer Number",customer_record[13:])
print("First 8 characters",customer_record[:8])
print("Last 5 characters:",customer_record[14:])
print("Every second character:",customer_record[::2])
print("Every third character:",customer_record[::3])
print("Entire record in reverse:",customer_record[::-1])
# Out:
# Customer Prefix: CUS
# City Code: LAG
# Registration Year: 2026
# Customer Number 000451
# First 8 characters CUS-LAG-
# Last 5 characters: 00451
# Every second character: CSLG22-041
# Every third character: C-G0-01
# Entire record in reverse: 154000-6202-GAL-SUC

# %%
customer_name = "Christopher Johnson"

print("First Name:",customer_name[:11])
print("Last Name",customer_name[12:])
print("First 5 letters of the first name:",customer_name[:5])
print("Last 7 letters of the last name",customer_name[-7:])
print("Entire name in reverse:",customer_name[::-1])
# Out:
# First Name: Christopher
# Last Name Johnson
# First 5 letters of the first name: Chris
# Last 7 letters of the last name Johnson
# Entire name in reverse: nosnhoJ rehpotsirhC
