# %% [markdown]
# # Exercise 1

# %%
username_correct = True
password_correct = True
account_locked = False

if username_correct and password_correct and not account_locked:
    print("Access Granted")
    
else:
    print("Access Denied")
# Out:
# Access Granted

# %% [markdown]
# # Exercise 2

# %%
score = 85
participated = True
low_income = False

if (score >=80 and participated) or low_income:
    print("Congratulations!")
    print("Scholarship Approved.")
    
else:
    print("Scholarship Not Approved.")
# Out:
# Congratulations!
# Scholarship Approved.

# %% [markdown]
# # Exercise 3

# %%
cpu_usage = 75
memory_usage = 92
disk_usage = 60


if cpu_usage > 90 or memory_usage > 90 or disk_usage >95:
    print("⚠️ Critical Alert!")
    
else:
    print("✅ System Healthy")
# Out:
# ⚠️ Critical Alert!

# %% [markdown]
# # Bonus Challenge

# %%
is_logged_in = True
item_in_stock = False
saved_payment = False
enough_wallet_balance = True
account_suspended = True

if is_logged_in and item_in_stock and saved_payment or (enough_wallet_balance or not account_suspended):
    print("✅ Order Confirmed")
    
else:
    print("❌ Order Failed")
# Out:
# ✅ Order Confirmed

# %% [markdown]
# ### First scenario
#
# ##### is_logged_in = True
# ##### item_in_stock = True
# ##### saved_payment = True
# ##### enough_wallet_balance = False
# ##### account_suspended = False
#
# ##### if (is_logged_in and item_in_stock) and saved_payment or enough_wallet_balance and not account_suspended:
# #####     print("✅ Order Confirmed")
#
# ##### else:
# #####     print("❌ Order Failed")
#
# #### This resulted in order confirmation because:
# ##### 1.The argument in the parentheses is True and True == True
# ##### 2. The not argument resverse is False to True
# ##### 3. For the "and" and "or" argument; the "and" argument is True and the "or" argument is False, this result to True which printed Order Confirm
#
# #### This means True and True or False and True (This result is True)

# %% [markdown]
# ### Second scenario
#
# ##### is_logged_in = True
# ##### item_in_stock = False
# ##### saved_payment = True
# ##### enough_wallet_balance = False
# ##### account_suspended = False
#
# ##### if (is_logged_in and item_in_stock) and saved_payment or enough_wallet_balance and not account_suspended:
# #####     print("✅ Order Confirmed")
#
# ##### else:
# #####     print("❌ Order Failed")
#
# #### This resulted in order Failed because:
# ##### 1.The argument in the parentheses is True and False == False
# ##### 2. The not argument resverse the False to True
# ##### 3. The "and" argument is True and the "or" is False making the statement True which printed Order Failed
#
# ##### This means False and True or False and True (This result is False)

# %% [markdown]
# ### Third scenario
# #### is_logged_in = True
# #### item_in_stock = True
# #### saved_payment = False
# #### enough_wallet_balance = True
# #### account_suspended = True
#
# #### if is_logged_in and item_in_stock and saved_payment or (enough_wallet_balance or not account_suspended):
# ####     print("✅ Order Confirmed")
#
# #### else:
# ####     print("❌ Order Failed")
#
# #### This resulted in Order Confirmed because:
# #### 1. The first argument examine is the parentheses due to precedence and this is True or not True == True or False
# #### 2. The next is the first "and" argument which are both True
# #### 3. The second " and" argument is False but the "or" argument on the right is True which == True which print Order Confirm
#
# #### This means True and False or True

# %% [markdown]
# ### Fourth scenario
# #### is_logged_in = True
# #### item_in_stock = False
# #### saved_payment = False
# #### enough_wallet_balance = True
# #### account_suspended = True
#
# #### if is_logged_in and item_in_stock and saved_payment or (enough_wallet_balance or not account_suspended):
# ####     print("✅ Order Confirmed")
#
# #### else:
# ####     print("❌ Order Failed")
#
# #### This resulted in Order Confirmed because:
# #### 1. The first argument examine is the parentheses due to precedence and this is True or not True == True or False
# #### 2. The next argument which are True and False and False or True == True
#
# #### This means False and True or True
