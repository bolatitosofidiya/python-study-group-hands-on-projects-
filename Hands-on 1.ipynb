# %% [markdown]
# # Exercise 1

# %%
print("Hello World")
print("My Name is Bolatito.")
print("I am learning Python.")
print("Programming is exciting!")
# Out:
# Hello World
# My Name is Bolatito.
# I am learning Python.
# Programming is exciting!

# %% [markdown]
# # Exercise 2

# %%
print("My favorite food is Spaghetti.")
# Out:
# My favorite food is Spaghetti.

# %%
print("My favorite movie is Horrible Boss.")
# Out:
# My favorite movie is Horrible Boss.

# %%
print("My favorite sport is 100m Race.")
# Out:
# My favorite sport is 100m Race.

# %%
print("My favorite color is Blue.")
# Out:
# My favorite color is Blue.

# %% [markdown]
# # Exercise 3

# %%
print(15 + 5)
# Out:
# 20

# %%
print(30 - 12)
# Out:
# 18

# %%
print(9*8)
# Out:
# 72

# %%
print(72/9)
# Out:
# 8.0

# %%
print(18%5)
# Out:
# 3

# %%
print(10//3)
# Out:
# 3

# %%
print(5**2)
# Out:
# 25

# %% [markdown]
# # Exercise 4

# %%
# Display programming language
print("Python")
# Out:
# Python

# %%
# Display first Topic
print("Programming")
# Out:
# Programming

# %%
# Show current lesson
print("Lesson One")
# Out:
# Lesson One

# %% [markdown]
# # Exercise 5

# %%
print("My name is Bolatito.")
# Out:
# My name is Bolatito.

# %%
print("My dream career is to become a data consultant.")
# Out:
# My dream career is to become a data consultant.

# %%
print("My country is Nigeria.")
# Out:
# My country is Nigeria.

# %%
print(25+75)
# Out:
# 100

# %%
print(40//6)
# Out:
# 6

# %% [markdown]
# # Python Practice

# %% [markdown]
# # First notebook

# %% [markdown]
# # Beginners journey
